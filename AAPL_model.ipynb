# %%
import requests
import pandas as pd

def get_data(ticker_id, api_key):
    url = f"https://api.tiingo.com/tiingo/daily/{ticker_id}/prices"
    params = {
        'startDate': '2010-01-01',
        'format': 'json',  # Use 'json' instead of 'csv' for JSON response
        'resampleFreq': 'daily',
        'token': api_key,
    }
    response = requests.get(url, params=params)
    data = response.json()
    return data

    
api_key = "5f9b868e8158bbcbed75f0549ff6f14b7a62b8f8"
ticker_symbol = "MSFT"

data = get_data(ticker_symbol, api_key)
data1 = pd.DataFrame(data)
data1
# Out:
#                           date    close    high     low    open    volume  \
# 0     2010-01-04T00:00:00.000Z   30.950   31.10   30.59   30.62  38409100
# 1     2010-01-05T00:00:00.000Z   30.960   31.10   30.64   30.85  49749600
# 2     2010-01-06T00:00:00.000Z   30.770   31.08   30.52   30.88  58182400
# 3     2010-01-07T00:00:00.000Z   30.452   30.70   30.19   30.63  50559700
# 4     2010-01-08T00:00:00.000Z   30.660   30.88   30.24   30.28  51197400
# ...                        ...      ...     ...     ...     ...       ...
# 3554  2024-02-16T00:00:00.000Z  404.060  408.29  403.44  407.96  22296495
# 3555  2024-02-20T00:00:00.000Z  402.790  404.49  398.01  403.24  24307915
# 3556  2024-02-21T00:00:00.000Z  402.180  402.29  397.22  400.17  18631072
# 3557  2024-02-22T00:00:00.000Z  411.650  412.83  408.57  410.19  27009869
# 3558  2024-02-23T00:00:00.000Z  410.340  415.86  408.97  415.67  16295879
#
#         adjClose     adjHigh      adjLow     adjOpen  adjVolume  divCash  \
# ...
